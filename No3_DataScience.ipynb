# %%
print("===NO1===")
print("---1A---")
dadu = 6

a = 3
b = 2
c = 4
d = 5
e = 6
f = 1
g = 5
h = 6
i = 3
j = 2
k = 2
l = 1
m = 3
n = 1
o = 5

percobaan1 = (a/dadu)
print("Percobaan 1 : " +str(percobaan1))
percobaan2 = (b/dadu)
print("Percobaan 2 : " +str(percobaan2))
percobaan3 = (c/dadu)
print("Percobaan 3 : " +str(percobaan3))
percobaan4 = (d/dadu)
print("Percobaan 4 : " +str(percobaan4))
percobaan5 = (e/dadu)
print("Percobaan 5 : " +str(percobaan5))
percobaan6 = (f/dadu)
print("Percobaan 6 : " +str(percobaan6))
percobaan7 = (g/dadu)
print("Percobaan 7 : " +str(percobaan7))
percobaan8 = (h/dadu)
print("Percobaan 8 : " +str(percobaan8))
percobaan9 = (i/dadu)
print("Percobaan 9 : " +str(percobaan9))
percobaan10 = (j/dadu)
print("Percobaan 10 : " +str(percobaan10))
percobaan11= (k/dadu)
print("Percobaan 11 : " +str(percobaan11))
percobaan12 = (l/dadu)
print("Percobaan 12 : " +str(percobaan12))
percobaan13 = (m/dadu)
print("Percobaan 13 : " +str(percobaan13))
percobaan14 = (n/dadu)
print("Percobaan 14 : " +str(percobaan14))
percobaan15 = (o/dadu)
print("Percobaan 15 : " +str(percobaan15))
jumlah = (percobaan1+percobaan2+percobaan3+percobaan4+percobaan5+percobaan6+percobaan7+percobaan8+percobaan9+percobaan10+percobaan11+percobaan12+percobaan13+percobaan14+percobaan15)
print("Jumlah Seluruh : " +str(jumlah))
kurang = (percobaan1+percobaan2+percobaan3+percobaan6+percobaan9+percobaan10+percobaan11+percobaan12+percobaan13+percobaan14)
print("Jumlah <5 : " +str(kurang))
print("---1B---")
dadu1 = 12
a1 = 9
a2 = 11
a3 = 3
a4 = 6          
a5 = 2
a6 = 4
a7 = 9
a8 = 12
a9 = 10
a10 = 8
a11 = 2
a12 = 6
a13 = 3
a14 = 4
a15 = 9
a16 = 8
a17 = 5
a18 = 6
a19 = 11
a20 = 10

x1 = (a1/dadu1)
print("2 Buah Dadu Di Lempar : " +str(x1))
x2 = (a2/dadu1)
print("2 Buah Dadu Di Lempar : " +str(x2))
x3 = (a3/dadu1)
print("2 Buah Dadu Di Lempar : " +str(x3))
x4 = (a4/dadu1)
print("2 Buah Dadu Di Lempar : " +str(x4))
x5 = (a5/dadu1)
print("2 Buah Dadu Di Lempar : " +str(x5))
x6 = (a6/dadu1)
print("2 Buah Dadu Di Lempar : " +str(x6))
x7 = (a7/dadu1)
print("2 Buah Dadu Di Lempar : " +str(x7))
x8 = (a8/dadu1)
print("2 Buah Dadu Di Lempar : " +str(x8))
x9 = (a9/dadu1)
print("2 Buah Dadu Di Lempar : " +str(x9))
x10 = (a10/dadu1)
print("2 Buah Dadu Di Lempar : " +str(x10))
x11 = (a11/dadu1)
print("2 Buah Dadu Di Lempar : " +str(x11))
x12 = (a12/dadu1)
print("2 Buah Dadu Di Lempar : " +str(x12))
x13 = (a13/dadu1)
print("2 Buah Dadu Di Lempar : " +str(x13))
x14 = (a14/dadu1)
print("2 Buah Dadu Di Lempar : " +str(x14))
x15 = (a15/dadu1)
print("2 Buah Dadu Di Lempar : " +str(x15))
x16 = (a16/dadu1)
print("2 Buah Dadu Di Lempar : " +str(x16))
x17 = (a17/dadu1)
print("2 Buah Dadu Di Lempar : " +str(x17))
x18 = (a18/dadu1)
print("2 Buah Dadu Di Lempar : " +str(x18))
x19 = (a19/dadu1)
print("2 Buah Dadu Di Lempar : " +str(x19))
x20 = (a20/dadu1)
print("2 Buah Dadu Di Lempar : " +str(x20))
jmlh = (x1+x2+x3+x4+x5+x6+x7+x8+x9+x10+x11+x12+x13+x14+x15+x16+x17+x18+x19+x20)
print("Jumlah Seluruh : " +str(jmlh))
gg = 6
g1 = 6
g2 = 2
g3 = 4
g4 = 12
g5 = 10
g6 = 8
g7 = 2
g8 = 6
g9 = 4
g10 = 8
g11 = 6
g12 = 10
genap1 = (g1/gg)
print("hasil genap : " +str(genap1))
genap2 = (g2/gg)
print("hasil genap : " +str(genap2))
genap3 = (g3/gg)
print("hasil genap : " +str(genap3))
genap4 = (g4/gg)
print("hasil genap : " +str(genap4))
genap5 = (g5/gg)
print("hasil genap : " +str(genap5))
genap6 = (g6/gg)
print("hasil genap : " +str(genap6))
genap7 = (g7/gg)
print("hasil genap : " +str(genap7))
genap8 = (g8/gg)
print("hasil genap : " +str(genap8))
genap9 = (g9/gg)
print("hasil genap : " +str(genap9))
genap10 = (g10/gg)
print("hasil genap : " +str(genap10))
genap11 = (g11/gg)
print("hasil genap : " +str(genap11))
genap12 = (g12/gg)
print("hasil genap : " +str(genap12))
gnp = (genap1+genap2+genap3+genap4+genap5+genap6+genap7+genap8+genap9+genap10+genap11+genap12)
print("Hasil Keseluruhan Genap : " +str(gnp))
print("")
# Out:
# ===NO1===
# ---1A---
# Percobaan 1 : 0.5
# Percobaan 2 : 0.3333333333333333
# Percobaan 3 : 0.6666666666666666
# Percobaan 4 : 0.8333333333333334
# Percobaan 5 : 1.0
# Percobaan 6 : 0.16666666666666666
# Percobaan 7 : 0.8333333333333334
# Percobaan 8 : 1.0
# Percobaan 9 : 0.5
# Percobaan 10 : 0.3333333333333333
# Percobaan 11 : 0.3333333333333333
# Percobaan 12 : 0.16666666666666666
# Percobaan 13 : 0.5
# Percobaan 14 : 0.16666666666666666
# Percobaan 15 : 0.8333333333333334
# Jumlah Seluruh : 8.166666666666666
# Jumlah <5 : 3.666666666666667
# ---1B---
# 2 Buah Dadu Di Lempar : 0.75
# 2 Buah Dadu Di Lempar : 0.9166666666666666
# 2 Buah Dadu Di Lempar : 0.25
# 2 Buah Dadu Di Lempar : 0.5
# 2 Buah Dadu Di Lempar : 0.16666666666666666
# 2 Buah Dadu Di Lempar : 0.3333333333333333
# 2 Buah Dadu Di Lempar : 0.75
# 2 Buah Dadu Di Lempar : 1.0
# 2 Buah Dadu Di Lempar : 0.8333333333333334
# 2 Buah Dadu Di Lempar : 0.6666666666666666
# 2 Buah Dadu Di Lempar : 0.16666666666666666
# ...

# %%
print("===NO2===")
print("---2A---")
print("Minggu 1")
m1 = 6560860
m2 = 5950850
m3 = 12685900
m4 = 5768500
m5 = 2989000
minggu1 = (m1+m2+m3+m4+m5)
print("Pendapatan Minggu Ke 1 : " +str(minggu1))
print("Minggu 2")
m6 = 8782150
m7 = 6620000
m8 = 5128750
m9 = 5217300
m10 = 4820600
minggu2 = (m6+m7+m8+m9+m10)
print("Pendapatan Minggu Ke 2 : "+str(minggu2))
print("Minggu 3")
m11 = 8130940
m12 = 2940650
m13 = 3488200
m14 = 6930540
m15 = 4319260
minggu3 = (m11+m12+m13+m14+m15)
print("Pendapatan Minggu Ke 3 : "+str(minggu3))
print("Minggu 4")
m16 = 12849100
m17 = 5752200
m18 = 5128400
m19 = 3880490
m20 = 4982100
minggu4 = (m16+m17+m18+m19+m20)
print("Pendapatan Minggu ke 4 : "+str(minggu4))
print()
import matplotlib.pyplot as plt

fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
usai = ['Minggu Ke 1','Minggu Ke 2','Minggu Ke 3','Minggu Ke 4']
orla = [33955110,30568800,25809590,32592290]
c = ['orange','yellow', 'blue']
plt.title("TOTAL PENDAPATAN PER MINGGU")
ax.bar(usai,orla, color=c)
plt.show()
print()

import matplotlib.pyplot as plt

fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.axis('equal')
plt.title('TOTAL PENDAPATAN PER MINGGU')
jurusan=['Minggu Ke 1','Minggu Ke 2','Minggu Ke 3','Minggu Ke 4']
orla = [33955110,30568800,25809590,32592290]
ax.pie(orla,labels=jurusan,autopct='%1.2f%%')

plt.show()
print("---2B---")
# Out:
# ===NO2===
# ---2A---
# Minggu 1
# Pendapatan Minggu Ke 1 : 33955110
# Minggu 2
# Pendapatan Minggu Ke 2 : 30568800
# Minggu 3
# Pendapatan Minggu Ke 3 : 25809590
# Minggu 4
# Pendapatan Minggu ke 4 : 32592290
# ---2B---
